# %% [markdown]
# <a href="https://colab.research.google.com/github/Babithrai/udhbav_internship/blob/main/placementdataanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("/House_Rent_Dataset.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data1=data.copy()

# %%
data1
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
data1.shape
# Out:
# (4746, 12)

# %%
data1.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
data1.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
data1.head(8)
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
# 5  2022-04-29    2   7000   600  Ground out of 1   Super Area
# 6  2022-06-21    2  10000   700  Ground out of 4   Super Area
# 7  2022-06-21    1   5000   250       1 out of 2   Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
data1.tail(3)
# Out:
#        Posted On  BHK   Rent  Size         Floor    Area Type  \
# 4743  2022-07-10    3  35000  1750    3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500  23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000    4 out of 5  Carpet Area
#
#              Area Locality       City Furnishing Status  Tenant Preferred  \
# 4743  Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744            Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745       Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner

# %%
data1.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
#splitting x and y
x=data1.iloc[:,:-2].values
y=data1.iloc[:,-1].values

# %%
print(x)
# Out:
# [['2022-05-18' 2 10000 ... 'Kolkata' 'Unfurnished' 'Bachelors/Family']
#  ['2022-05-13' 2 20000 ... 'Kolkata' 'Semi-Furnished' 'Bachelors/Family']
#  ['2022-05-16' 2 17000 ... 'Kolkata' 'Semi-Furnished' 'Bachelors/Family']
#  ...
#  ['2022-07-10' 3 35000 ... 'Hyderabad' 'Semi-Furnished'
#   'Bachelors/Family']
#  ['2022-07-06' 3 45000 ... 'Hyderabad' 'Semi-Furnished' 'Family']
#  ['2022-05-04' 2 15000 ... 'Hyderabad' 'Unfurnished' 'Bachelors']]

# %%
print(y)
# Out:
# ['Contact Owner' 'Contact Owner' 'Contact Owner' ... 'Contact Agent'
#  'Contact Agent' 'Contact Owner']

# %%
from sklearn.impute import SimpleImputer
imputer_y =SimpleImputer(missing_values=np.nan, strategy='mean')
imputer_y.fit(y.reshape(-1,1))
y= imputer_y.transform(y.reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-37-608b49fcfb0a> in <cell line: 3>()
#       1 from sklearn.impute import SimpleImputer
#       2 imputer_y =SimpleImputer(missing_values=np.nan, strategy='mean')
# ----> 3 imputer_y.transform(y.reshape(-1,1))
#       4 y= imputer_y.transform(y.reshape(-1,1))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py in transform(self, X)
#     547             `X` with imputed values.
#     548         """
# ...

# %%
print(y)
# Out:
# ['Contact Owner' 'Contact Owner' 'Contact Owner' ... 'Contact Agent'
#  'Contact Agent' 'Contact Owner']

# %%
data1.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
#encoding categorical data that ddosent have binary result
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2])], remainder='passthrough')
x=np.array(ct.fit_transform(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py in _hstack(self, Xs)
#     829                 # dtype conversion if necessary.
# --> 830                 converted_Xs = [
#     831                     check_array(X, accept_sparse=True, force_all_finite=False)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py in <listcomp>(.0)
#     830                 converted_Xs = [
# --> 831                     check_array(X, accept_sparse=True, force_all_finite=False)
#     832                     for X in Xs
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
# ...

# %%
print(x)
# Out:
# [[ 1.          0.         -0.23221018 ... -0.72444647 -1.29109087
#   -0.59764672]
#  [ 0.          1.         -0.23221018 ...  1.38036423  1.08715679
#    0.6876202 ]
#  [ 1.          0.          4.30644338 ... -0.72444647  0.21890765
#   -0.76947385]
#  ...
#  [ 1.          0.         -0.23221018 ...  1.38036423 -0.98909117
#    1.27870553]
#  [ 1.          0.         -0.23221018 ... -0.72444647 -0.15859198
#   -0.35193393]
#  [ 0.          1.         -0.23221018 ... -0.72444647  1.27590661
#   -0.3536522 ]]

# %%
print(x)
# Out:
# [[ 1.          0.         -0.23221018 ... -0.72444647 -1.29109087
#   -0.59764672]
#  [ 0.          1.         -0.23221018 ...  1.38036423  1.08715679
#    0.6876202 ]
#  [ 1.          0.          4.30644338 ... -0.72444647  0.21890765
#   -0.76947385]
#  ...
#  [ 1.          0.         -0.23221018 ...  1.38036423 -0.98909117
#    1.27870553]
#  [ 1.          0.         -0.23221018 ... -0.72444647 -0.15859198
#   -0.35193393]
#  [ 0.          1.         -0.23221018 ... -0.72444647  1.27590661
#   -0.3536522 ]]

# %%
#encoding categorical data that have binary result
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x[:,6]= le.fit_transform(x[:,6])

# %%
print(x)
# Out:
# [[ 1.          0.         -0.23221018 ... -0.72444647 -1.29109087
#   -0.59764672]
#  [ 0.          1.         -0.23221018 ...  1.38036423  1.08715679
#    0.6876202 ]
#  [ 1.          0.          4.30644338 ... -0.72444647  0.21890765
#   -0.76947385]
#  ...
#  [ 1.          0.         -0.23221018 ...  1.38036423 -0.98909117
#    1.27870553]
#  [ 1.          0.         -0.23221018 ... -0.72444647 -0.15859198
#   -0.35193393]
#  [ 0.          1.         -0.23221018 ... -0.72444647  1.27590661
#   -0.3536522 ]]

# %%
#feature scoling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x = sc.fit_transform(x)

# %%
print(x)
# Out:
# [[ 0.85666269 -0.85666269 -0.23221018 ... -0.72444647 -1.29109087
#   -0.59764672]
#  [-1.16732059  1.16732059 -0.23221018 ...  1.38036423  1.08715679
#    0.6876202 ]
#  [ 0.85666269 -0.85666269  4.30644338 ... -0.72444647  0.21890765
#   -0.76947385]
#  ...
#  [ 0.85666269 -0.85666269 -0.23221018 ...  1.38036423 -0.98909117
#    1.27870553]
#  [ 0.85666269 -0.85666269 -0.23221018 ... -0.72444647 -0.15859198
#   -0.35193393]
#  [-1.16732059  1.16732059 -0.23221018 ... -0.72444647  1.27590661
#   -0.3536522 ]]

# %%
#splitting the data into the training set and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train)
# Out:
# [[ 0.85666269 -0.85666269 -0.23221018 ... -0.72444647 -0.00759213
#   -1.18014069]
#  [-1.16732059  1.16732059 -0.23221018 ...  1.38036423 -1.29109087
#   -0.04779991]
#  [ 0.85666269 -0.85666269 -0.23221018 ...  1.38036423  1.76363613
#   -0.02030757]
#  ...
#  [-1.16732059  1.16732059 -0.23221018 ... -0.72444647 -0.00759213
#   -0.48252255]
#  [-1.16732059  1.16732059 -0.23221018 ... -0.72444647  0.25665761
#    1.69452718]
#  [ 0.85666269 -0.85666269 -0.23221018 ...  1.38036423 -1.10234106
#   -0.16636063]]
